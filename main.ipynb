# %% [markdown]
# <a href="https://colab.research.google.com/github/Jforjoe95/ADALL_github/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
import pandas as pd

# %%
import numpy as np

# %%
github_raw_url = "https://raw.githubusercontent.com/Jforjoe95/ADALL_github/refs/heads/main/laptop_prices_2024_sgd_TL.csv"
df = pd.read_csv(github_raw_url)
print("Successfully loaded data from GitHub!")
display(df.head())
# Out:
# Successfully loaded data from GitHub!
#   Brand                Model                        CPU              GPU  \
# 0  Acer             Aspire 5           Intel i9-14900HK  NVIDIA RTX 4070
# 1  Acer              Nitro 5         AMD Ryzen 9 8900HX  AMD Radeon 780M
# 2  Acer              Nitro 5          AMD Ryzen 5 8600H  NVIDIA RTX 4050
# 3  Acer        TravelMate P6  Intel Core Ultra 7 15500H  NVIDIA RTX 4060
# 4  Acer  Predator Helios 300            Intel i7-14800H  NVIDIA RTX 4070
#
#    RAM_GB Storage_Type  Storage_GB  Touchscreen  Weight_kg  Screen_Size_inch  \
# 0      64          SSD         256        False       1.56              16.0
# 1      32          SSD        1024         True       1.45              14.0
# 2      32          SSD        2048        False       1.34              14.0
# 3      16          SSD        4096         True       1.18              13.3
# 4       8          SSD        1024         True       1.31              14.0
#
#    Discount_percent  Price_SGD  Brand_Discount  Member_Discount
# 0              3.27    2413.36               5           144.80
# 1              5.03    1773.75               5           124.16
# 2              4.41    1634.07               5            98.04
# 3              2.16    2362.59               5           118.13
# 4              6.93    2218.55               5           155.30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   object
#  1   Model             1000 non-null   object
#  2   CPU               1000 non-null   object
#  3   GPU               1000 non-null   object
#  4   RAM_GB            1000 non-null   int64
#  5   Storage_Type      1000 non-null   object
#  6   Storage_GB        1000 non-null   int64
#  7   Touchscreen       1000 non-null   bool
#  8   Weight_kg         1000 non-null   float64
#  9   Screen_Size_inch  1000 non-null   float64
#  10  Discount_percent  1000 non-null   float64
#  11  Price_SGD         1000 non-null   float64
#  12  Brand_Discount    1000 non-null   int64
#  13  Member_Discount   1000 non-null   float64
# dtypes: bool(1), float64(5), int64(3), object(5)
# memory usage: 102.7+ KB

# %%
from google.colab import userdata
from openai import OpenAI


# Load key from Google Colab Secrets
api_key = userdata.get('OPENAI_API_KEY')

client = OpenAI(
    # This is the default and can be omitted
    api_key=api_key,
)

response = client.responses.create(
    model="gpt-5-mini",
    instructions="You are a data analyst expert who uses Python.",
    input="What is Exploratory Data Analysis?",
)

print(response.output_text)
# Out:
# Exploratory Data Analysis (EDA) is the process of summarizing, visualizing, and probing a dataset to understand its main characteristics, uncover patterns, detect anomalies, test assumptions, and guide subsequent modeling or decision-making. It's an early, iterative, and often informal investigation that blends statistics, visualization, and domain knowledge.
#
# Key goals
# - Understand dataset structure (variables, types, completeness).
# - Summarize distributions and central tendencies.
# - Reveal relationships and correlations between features.
# - Detect missing values, outliers, and data quality issues.
# - Generate hypotheses and guide feature engineering and modeling choices.
#
# Typical steps
# 1. Data ingestion and overview
#    - Load data, inspect shape, data types, memory usage.
#    - Quick summary: head, tail, sample rows.
# 2. Data quality checks
#    - Missing values, duplicates, inconsistent or impossible values.
#    - Type problems (numeric stored as text).
# 3. Univariate analysis
#    - Summary statistics (mean, median, std, quantiles).
#    - Distribution plots (histogram, KDE, bar chart for categoricals).
# 4. Multivariate analysis
#    - Correlations (Pearson/Spearman), cross-tabs, pivot tables.
#    - Scatter plots, pairplots, group summaries.
# 5. Outliers and anomalies
#    - Boxplots, z-scores, IQR method, domain checks.
# 6. Feature relationships and segmentation
#    - Conditional distributions, interaction effects, time series trends.
# 7. Transformations and feature creation
#    - Normalization, log transforms, binning, encoding, derived features.
# 8. Document findings and next steps
#    - Hypotheses, recommended cleaning, modeling implications.
#
# Common techniques and visuals
# - Summary tables: describe(), value_counts()
# - Missing-value visualization: heatmap, missingno.matrix()
# - Distributions: histograms, KDEs, boxplots
# - Relationships: scatter plots, pairplots, heatmap of correlations
# - Categorical summaries: bar plots, stacked bars, pivot tables
# - Time series: line plots, rolling statistics
#
# Tools and libraries (Python)
# - pandas, numpy for data manipulation
# - matplotlib, seaborn for plotting
# - plotly for interactive visuals
# - missingno, dtale for quick EDA tools
# - pandas-profiling (ydata-profiling), Sweetviz for automated reports
# - scikit-learn for preprocessing and basic feature utilities
#
# Simple Python EDA starter snippet
# - (Assumes pandas, seaborn, matplotlib are installed)
#
# from matplotlib import pyplot as plt
# import seaborn as sns
# import pandas as pd
#
# df = pd.read_csv("data.csv")
# print(df.info())
# print(df.describe(include='all'))
# print(df.isna().sum())
#
# # Univariate
# df['numeric_col'].hist(bins=30)
# plt.show()
# sns.boxplot(x=df['numeric_col'])
# plt.show()
#
# # Multivariate
# sns.scatterplot(data=df, x='feature1', y='feature2', hue='target')
# plt.show()
# sns.heatmap(df.corr(), annot=True)
# plt.show()
#
# Best practices
# - Start broad, then zoom into interesting parts of the data.
# - Combine visual and numeric summaries.
# - Use domain knowledge to interpret anomalies before automatic cleaning.
# - Work reproducibly (scripts, notebooks, version control).
# - Sample large datasets for quick iteration, then scale up checks.
# - Record assumptions, decisions, and open questions.
#
# Common pitfalls
# - Overlooking data leakage or target leakage when exploring.
# - Relying only on automated EDA reports without domain validation.
# - Misinterpreting correlations as causation.
# - Ignoring issues in categorical encodings, dates, or text fields.
#
# Deliverables of EDA
# - Cleaned and annotated dataset or data-cleaning plan.
# - Summary report (notebook or slides) with key charts, statistics, and next steps.
# - Feature ideas and recommended preprocessing for modeling.
#
# If you want, I can:
# - Walk through an EDA on a specific dataset you provide.
# - Generate a sample notebook template for EDA.
# - Produce an automated profiling report from a CSV you upload.

# %%
# Convert the first few rows to a string to send to OpenAI
data_preview = df.head(10).to_csv(index=False)
print(data_preview)

response = client.responses.create(
  model="gpt-5-mini",
  instructions="You are an expert data scientist with extensive knowledge of predictive analysis and linear regression.",
  input=f"Dataset: Laptop Price Prdiction (1000 samples, 14 features, traget is Price_SGD)\nHere are the first 10 rows of the dataset:\n{data_preview}]",
)
print(response.output_text)

# %%
# Convert the first few rows to a string to send to OpenAI
data_preview = df.head(10).to_csv(index=False)
print(data_preview)

response = client.responses.create(
  model="gpt-5-mini",
  instructions="You are an expert data scientist with extensive knowledge of predictive analysis and linear regression.",
  input=f"Dataset: Laptop Price Prdiction (1000 samples, 14 features, traget is Price_SGD)\nHere are the first 10 rows of the dataset:\n{data_preview}]",
)
print(response.output_text)
# Out:
# Brand,Model,CPU,GPU,RAM_GB,Storage_Type,Storage_GB,Touchscreen,Weight_kg,Screen_Size_inch,Discount_percent,Price_SGD,Brand_Discount,Member_Discount
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4070,64,SSD,256,False,1.56,16.0,3.27,2413.36,5,144.8
# Acer,Nitro 5,AMD Ryzen 9 8900HX,AMD Radeon 780M,32,SSD,1024,True,1.45,14.0,5.03,1773.75,5,124.16
# Acer,Nitro 5,AMD Ryzen 5 8600H,NVIDIA RTX 4050,32,SSD,2048,False,1.34,14.0,4.41,1634.07,5,98.04
# Acer,TravelMate P6,Intel Core Ultra 7 15500H,NVIDIA RTX 4060,16,SSD,4096,True,1.18,13.3,2.16,2362.59,5,118.13
# Acer,Predator Helios 300,Intel i7-14800H,NVIDIA RTX 4070,8,SSD,1024,True,1.31,14.0,6.93,2218.55,5,155.3
# Acer,Aspire 5,Intel i9-14900HK,NVIDIA RTX 4080,32,SSD,256,False,3.34,17.3,8.94,2224.12,5,155.69
# Acer,TravelMate P6,Intel i9-14900HK,NVIDIA RTX 4080,128,SSD,1024,True,1.11,13.3,11.72,3016.36,5,211.15
# Acer,Predator Helios 300,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,True,1.29,13.3,8.84,2579.29,5,180.55
# Acer,Swift 3,Intel i5-14500H,NVIDIA RTX 4050,64,SSD,4096,False,1.4,13.3,6.92,1976.94,5,98.85
# Acer,Nitro 5,Intel Core Ultra 9 15700H,NVIDIA RTX 4070,16,SSD,2048,False,1.15,13.3,5.25,2538.34,5,152.3
#
# Thanks — this is enough to get started. Below I’ll outline a practical, reproducible plan for building a predictive model (linear-regression–based baseline and stronger alternatives), plus concrete feature-engineering suggestions and a sample scikit-learn pipeline you can run. Tell me which parts you want me to do next (EDA, build baseline model, tune, full notebook, etc.).
#
# 1) Quick data observations from the sample
# - Mixed types: categorical (Brand, Model, CPU, GPU, Storage_Type, Touchscreen), numeric (RAM_GB, Storage_GB, Weight_kg, Screen_Size_inch, Discount_percent, Brand_Discount, Member_Discount), target Price_SGD.
# - Some categorical fields are high-cardinality (Model, CPU, GPU) — need special handling.
# - Possible multicollinearity (Brand_Discount and Member_Discount may correlate with Discount_percent; Model and Brand are related).
# - Consider log-transform of Price_SGD if the distribution is skewed.
#
# 2) Recommended modeling workflow
# - Data cleaning & parsing
#   - Consistency (trim/normalize strings, lowercase).
#   - Convert Touchscreen to 0/1.
#   - Parse CPU/GPU strings into meaningful features (vendor: Intel/AMD/Apple, family: i3/i5/i7/i9/Core Ultra/Ryzen, generation number or “high/medium/low” performance buckets). For GPU, extract family (RTX 40xx vs integrated) and a generic performance tier.
#   - Create a Model-level aggregator (median price per Model from training set) for use as a feature or for grouping rare Models into "Other".
# - Exploratory Data Analysis (EDA)
#   - Histograms, boxplots of Price and log(Price).
#   - Correlations (numeric) and group-by price for categorical variables (Brand, Model, CPU, GPU).
#   - Check missing values and outliers.
# - Feature engineering
#   - Convert Storage_GB and RAM_GB into tiers (e.g., RAM: 8/16/32/64/128; Storage: <256, 256–512, 512–2000, >2000) or log-transform Storage_GB.
#   - Interaction features: Brand × Model (or Model embedding), CPU_family × GPU_tier, Screen_Size × Touchscreen, Weight × Screen_Size.
#   - Create price-per-GB or price-per-RAM features if helpful (after initial model).
#   - Encode temporal or market features if available (not in your sample).
# - Encoding categorical variables
#   - Low-cardinality (Brand, Storage_Type, Touchscreen): One-hot.
#   - High-cardinality (Model, CPU, GPU): target encoding (mean target per category), frequency encoding, or leave-one-out target encoding to avoid leakage. Another option: count/frequency encoding or grouping rare categories into "Other".
#   - Keep track of leakage: compute target-encodings only on training folds in cross-validation.
# - Train/validation design
#   - Use K-fold cross-validation (5 or 10 folds). If you have temporal ordering, use time-split.
#   - Consider nested CV for reliable hyperparameter selection.
# - Modeling progression
#   - Baseline: linear regression (OLS) with numeric features + simple encodings.
#   - Improved linear: regularized models (Ridge, Lasso, ElasticNet) with standardized inputs.
#   - Nonlinear/tree models: RandomForest, Gradient Boosting (XGBoost, LightGBM, CatBoost) — often give sizeable gains on tabular data.
#   - Ensembles: stacking linear + tree models.
# - Target transform
#   - If price is heteroscedastic or skewed, use log(Price_SGD) as target and exponentiate predictions. Use proper bias correction if needed (e.g., add 0.5*var when back-transforming with normal errors).
# - Evaluation metrics
#   - Primary: RMSE (or root mean squared log error if you model log price).
#   - Also report MAE and R^2.
#   - Use cross-validated distributions of metrics and report mean ± std.
# - Interpretation & diagnostics
#   - Residual plots vs predicted values and each feature.
#   - Check high-error cases (error analysis).
#   - Feature importance: coefficients (for linear) and SHAP values for tree models.
#
# 3) Example scikit-learn pipeline (skeleton)
# - Notes: This uses category_encoders.TargetEncoder (pip install category_encoders) and scikit-learn.
# - Pseudocode (Python):
#
# from sklearn.compose import ColumnTransformer
# from sklearn.pipeline import Pipeline
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import StandardScaler, OneHotEncoder
# from sklearn.linear_model import RidgeCV
# from category_encoders import TargetEncoder
# from sklearn.model_selection import cross_val_score, KFold
# import numpy as np
#
# numeric_feats = ['RAM_GB','Storage_GB','Weight_kg','Screen_Size_inch','Discount_percent','Brand_Discount','Member_Discount']
# low_card_cats = ['Brand','Storage_Type','Touchscreen']  # Touchscreen as 0/1 already
# high_card_cats = ['Model','CPU','GPU']
#
# numeric_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy='median')),
#     ('scaler', StandardScaler())
# ])
#
# low_card_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy='most_frequent')),
#     ('onehot', OneHotEncoder(handle_unknown='ignore'))
# ])
#
# high_card_transformer = Pipeline([
#     ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
#     ('target_enc', TargetEncoder())  # be careful to use within CV
# ])
#
# preprocessor = ColumnTransformer([
#     ('num', numeric_transformer, numeric_feats),
#     ('lowcat', low_card_transformer, low_card_cats),
#     ('highcat', high_card_transformer, high_card_cats)
# ])
#
# pipeline = Pipeline([
#     ('preproc', preprocessor),
#     ('model', RidgeCV(alphas=[0.1,1.0,10.0]))  # try other regularizers too
# ])
#
# cv = KFold(n_splits=5, shuffle=True, random_state=42)
# scores = -cross_val_score(pipeline, X, y_log, cv=cv, scoring='neg_root_mean_squared_error')  # if using log-target take care
# print('CV RMSE:', scores.mean(), scores.std())
#
# 4) Practical tips and pitfalls
# - Compute target-encodings only inside cross-validation folds (use wrappers or pipelines so encoders fit on training fold).
# - If many Model names, consider grouping by median price to reduce categories or use embeddings with neural nets.
# - Watch for data leakage: Brand_Discount and Member_Discount might be computed from final price or correlated with label—verify they’re legitimate features.
# - If you use log(target), remember to evaluate in original units for business interpretation.
# - Use SHAP to explain complex models (TreeExplainer for tree models) and partial dependence for key features.
#
# 5) Suggested experiments and hyperparameter grid
# - Linear family: Ridge (alpha in [1e-3,1e-2,1e-1,1,10,100]); Lasso for selection (alpha grid); ElasticNet (l1_ratio grid).
# - Tree family: RandomForest (n_estimators 200–1000, max_depth 6–20), LightGBM/XGBoost (learning_rate 0.01–0.2, n_estimators 200–2000, max_depth 4–12).
# - Encoding experiments: One-hot vs target encoding vs frequency encoding for Model/CPU/GPU.
# - Target transform: raw price vs log(price). Compare RMSE and residuals.
#
# 6) Deliverables I can produce for you (choose one or more)
# - Full EDA report (plots, correlation, distributions, outliers).
# - Cleaned dataset + engineered features (CSV).
# - Baseline linear regression model with CV and performance metrics.
# - Tuned model(s) (Ridge + LightGBM) with SHAP explanations and error analysis.
# - Ready-to-run Python notebook with all code and results.
#
# Which would you like me to do next? If you want runnable code, tell me whether I should:
# - operate on the full dataset you’ll upload, or
# - provide a self-contained notebook script you can run locally.
